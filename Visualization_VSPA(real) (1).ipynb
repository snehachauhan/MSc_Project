# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
pd.set_option('display.max_columns',None)

# %%
data=pd.read_csv("Video Streaming Platform Analysis.csv")

# %%
duplicate=data[data.duplicated()]
duplicate
# Out:
#            Timestamp 1.  Do you use Video Streaming Platform?  \
# 71     3/6/2021 9:40                                       No
# 156  3/22/2021 11:38                                      Yes
#
#     2. How frequently you watch or stream online platforms ?  \
# 71                                   None of the Above
# 156                                              Daily
#
#     3. Which of the following Video Streaming Platform do you currently use?  \
# 71                                             Hotstar
# 156                                              Prime
#
#     4. What do you watch the most on video streaming platform?   \
# 71                                       Documentaries
# 156                        Original web series, Movies
#
#     5. Which type of web series or movies do you prefer most?  \
# 71                                              Comedy
# 156                              Action, Drama, Comedy
#
#     6.  Have you watch or familiar with these original web series of Netflix.  \
# 71                                   None of the above
# 156                                     13 Reasons Why
#
#     7. Have you watch or familiar with these original web series of Amazon  Prime.  \
# 71                                   None of the above
# 156                                   Mirzapur, Tandav
#
#     8. Have you watch or familiar with these original web series of Hotstar.  \
# 71                                   None of the above
# 156                                  None of the above
#
#     9. Have you watch or familiar with these original web series of Hulu.  \
# 71                                   None of the above
# 156                                           Helstorm
#
#     10. What is your age?  \
# 71                  18-30
# 156                 18-30
#
#     11. From where did you get the idea of these web series.  \
# 71                                        Social Media
# 156                                       Social Media
#
#     12. On what basis you frequently choose your movies or web series.  \
# 71                                               Story
# 156                                              Story
#
#     13. How long you are using these video streaming platforms.  \
# 71                                                None
# 156                              Between 1 and 2 years
#
#     14. Choose the features which you think is essential on your streaming platforms.  \
# 71                                       Accessibility
# 156                                     Recommendation
#
#     15. How was your overall experience of using video streaming platforms.  \
# 71                                                Good
# 156                                               Good
#
#     16. Would you like to give any suggestion for the improvement.
# 71                                                 No
# 156                                 I want New stories

# %%
data=data.fillna(method='ffill')
data
# Out:
#            Timestamp 1.  Do you use Video Streaming Platform?  \
# 0     3/1/2021 16:41                                      Yes
# 1     3/1/2021 19:44                                      Yes
# 2     3/1/2021 20:44                                      Yes
# 3     3/1/2021 20:45                                      Yes
# 4     3/2/2021 21:06                                      Yes
# ..               ...                                      ...
# 237   4/12/2021 9:11                                      Yes
# 238   4/12/2021 9:12                                      Yes
# 239  4/12/2021 14:13                                      Yes
# 240  4/12/2021 23:13                                      Yes
# 241  4/12/2021 23:15                                      Yes
#
#     2. How frequently you watch or stream online platforms ?  \
# 0                              Once or twice in a week
# 1                                              Monthly
# 2                                                Daily
# 3                                                Daily
# 4                                                Daily
# ..                                                 ...
# 237                                              Daily
# 238                            Once or twice in a week
# 239                                              Daily
# 240                                              Daily
# 241                                              Daily
#
#     3. Which of the following Video Streaming Platform do you currently use?  \
# 0                       Netflix, Amazon Prime, Hotstar
# 1                                Netflix, Amazon Prime
# 2                 Netflix, Amazon Prime, Hotstar, Hulu
# 3                                                 Hulu
# 4                Netflix, Amazon Prime, Hotstar, Zee 5
# ..                                                 ...
# 237                            Netflix, Prime, Hotstar
# 238                                            Netflix
# 239                            Netflix, Prime, Hotstar
# 240                                              Prime
# 241                                     Netflix, Prime
#
#     4. What do you watch the most on video streaming platform?   \
# 0                          Original web series, Others
# 1                                               Movies
# 2    Original web series, Movies, Documentaries, Sp...
# 3                              Movies, Sports and News
# 4    Original web series, Movies, Documentaries, Sp...
# ..                                                 ...
# 237  Original web series, Movies, Documentaries, Sp...
# 238  Original web series, Movies, Documentaries, Sp...
# 239         Original web series, Movies, Documentaries
# 240                 Original web series, Documentaries
# 241         Original web series, Movies, Documentaries
#
#     5. Which type of web series or movies do you prefer most?  \
# 0                                       Comedy, Others
# 1                                Action, Drama, Comedy
# 2                        Action, Drama, Comedy, Horror
# 3                                               Action
# 4                                Action, Drama, Comedy
# ..                                                 ...
# 237                      Action, Drama, Comedy, Horror
# 238                             Action, Comedy, Horror
# 239                      Action, Drama, Comedy, Horror
# 240                                      Drama, Comedy
# 241              Action, Drama, Comedy, Horror, others
#
#     6.  Have you watch or familiar with these original web series of Netflix.  \
# 0                          Money Heist, Standup Comedy
# 1                                          Money Heist
# 2    Sacred Games, 13 Reasons Why, The Witcher, Mon...
# 3                          13 Reasons Why, The Witcher
# 4    Sacred Games, 13 Reasons Why, The Witcher, Mon...
# ..                                                 ...
# 237  Sacred Games, 13 Reasons Why, The Witcher, Mon...
# 238  Sacred Games, 13 Reasons Why, The Witcher, Mon...
# 239                                     13 Reasons Why
# 240                                  None of the above
# 241           13 Reasons Why, The Witcher, Money Heist
#
#     7. Have you watch or familiar with these original web series of Amazon  Prime.  \
# 0      Tandav, Standup Comedy , Family Man, Panchayat.
# 1              Standup Comedy , Family Man, Panchayat.
# 2    Mirjapur, Made in heaven, Tandav, Breath into ...
# 3    Made in heaven, Tandav, Breath into the shadow...
# 4    Mirjapur, Made in heaven, Tandav, Breath into ...
# ..                                                 ...
# 237                   Mirzapur, Made in heaven, Tandav
# 238                                           Mirzapur
# 239                                     Made in heaven
# 240                             Made in heaven, Tandav
# 241                                   Mirzapur, Tandav
#
#     8. Have you watch or familiar with these original web series of Hotstar.  \
# 0                              None of the above, Scam
# 1                                    None of the above
# 2    Special OPS, Hostages, Criminal Justice, Arya,...
# 3                                       Hostages, Arya
# 4    Special OPS, Hostages, Criminal Justice, Arya,...
# ..                                                 ...
# 237            Special OPS, Hostages, Criminal Justice
# 238                                  None of the above
# 239            Special OPS, Hostages, Criminal Justice
# 240                                  None of the above
# 241                                  None of the above
#
#     9. Have you watch or familiar with these original web series of Hulu.  \
# 0                                    None of the above
# 1                       The Ultimate Playlist of Noise
# 2    Helstorm, Monsterland, Woke, The Ultimate Play...
# 3                       Monsterland, None of the above
# 4                                    None of the above
# ..                                                 ...
# 237                                  None of the above
# 238                                  None of the above
# 239                                               Woke
# 240                                  None of the above
# 241                                  None of the above
#
#     10. What is your age?  \
# 0                   18-30
# 1                   18-30
# 2                   18-30
# 3                   18-30
# 4                   18-30
# ..                    ...
# 237                 18-30
# 238                 18-30
# 239                 18-30
# 240                 31-50
# 241                 18-30
#
#     11. From where did you get the idea of these web series.  \
# 0          Family/Friends Recommendation, Social Media
# 1          Family/Friends Recommendation, Social Media
# 2    Family/Friends Recommendation, Television, Soc...
# 3                             Television, Social Media
# 4    Family/Friends Recommendation, Television, Soc...
# ..                                                 ...
# 237  Family/Friends Recommendation, Television, Soc...
# 238                      Family/Friends Recommendation
# 239  Family/Friends Recommendation, Television, Soc...
# 240                 Social Media, Ads on OTT platforms
# 241        Family/Friends Recommendation, Social Media
#
#     12. On what basis you frequently choose your movies or web series.  \
# 0                                          Cast, Story
# 1                                      Story, Director
# 2                                                Story
# 3                                       Cast, Director
# 4                                          Cast, Story
# ..                                                 ...
# 237                              Cast, Story, Director
# 238                                              Story
# 239                              Cast, Story, Director
# 240                              Cast, Story, Director
# 241                                        Cast, Story
#
#     13. How long you are using these video streaming platforms.  \
# 0                                Between 1 and 2 years
# 1                                     Less than 1 year
# 2                                Between 1 and 2 years
# 3                                    More than 2 years
# 4                                    More than 2 years
# ..                                                 ...
# 237                              Between 1 and 2 years
# 238                                  More than 2 years
# 239                              Between 1 and 2 years
# 240                              Between 1 and 2 years
# 241                              Between 1 and 2 years
#
#     14. Choose the features which you think is essential on your streaming platforms.  \
# 0                          Recommendation, Ease of use
# 1                        Search option, Recommendation
# 2                        Search option, Recommendation
# 3                                          Ease of use
# 4                          Recommendation, Ease of use
# ..                                                 ...
# 237                        Recommendation, Ease of use
# 238                      Recommendation, Accessibility
# 239                         Search option, Ease of use
# 240                      Search option, Recommendation
# 241                      Search option, Recommendation
#
#     15. How was your overall experience of using video streaming platforms.  \
# 0                                                 Good
# 1                                            Excellent
# 2                                            Excellent
# 3                                            Excellent
# 4                                            Excellent
# ..                                                 ...
# 237                                          Excellent
# 238                                          Excellent
# 239                                          Excellent
# 240                                          Excellent
# 241                                               Good
#
#     16. Would you like to give any suggestion for the improvement.
# 0                             Yes, faster next season.
# 1                                                   No
# 2                                              Nothing
# 3                                              Nothing
# 4                Need more web series like Money Heist
# ..                                                 ...
# 237                                        Remove adds
# 238                                        Remove adds
# 239                             Limit the add duration
# 240                                            No need
# 241         yes need to decrease the membership amount
#
# [242 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['Timestamp', '1.  Do you use Video Streaming Platform?',
#        '2. How frequently you watch or stream online platforms ?',
#        '3. Which of the following Video Streaming Platform do you currently use?',
#        '4. What do you watch the most on video streaming platform? ',
#        '5. Which type of web series or movies do you prefer most?',
#        '6.  Have you watch or familiar with these original web series of Netflix.',
#        '7. Have you watch or familiar with these original web series of Amazon  Prime.',
#        '8. Have you watch or familiar with these original web series of Hotstar.',
#        '9. Have you watch or familiar with these original web series of Hulu.',
#        '10. What is your age?',
#        '11. From where did you get the idea of these web series.',
#        '12. On what basis you frequently choose your movies or web series.',
#        '13. How long you are using these video streaming platforms.',
#        '14. Choose the features which you think is essential on your streaming platforms.',
#        '15. How was your overall experience of using video streaming platforms.',
#        '16. Would you like to give any suggestion for the improvement.'],
#       dtype='object')

# %%
    data.rename(columns ={'1.  Do you use Video Streaming Platform?':'Video Streaming Platform(Y/N)', '2. How frequently you watch or stream online platforms ?':'Frequency of VSPA',
                           '3. Which of the following Video Streaming Platform do you currently use?':'Currently Used VSPA',
                           '4. What do you watch the most on video streaming platform? ':'Types',
                           '5. Which type of web series or movies do you prefer most?':'Genres',
                           '6.  Have you watch or familiar with these original web series of Netflix.':'Netflix Original Series',
                           '7. Have you watch or familiar with these original web series of Amazon  Prime.':'Prime Original Series',
                           '8. Have you watch or familiar with these original web series of Hotstar.':'Hotstar Original Series',
                            '9. Have you watch or familiar with these original web series of Hulu.':'Hulu Original Series',
                            '10. What is your age?':'Age',
                           '11. From where did you get the idea of these web series.':'advertisement',
                            '12. On what basis you frequently choose your movies or web series.':'Selection',
                           '13. How long you are using these video streaming platforms.':'Time Period',
                            '14. Choose the features which you think is essential on your streaming platforms.':'Features',
                            '15. How was your overall experience of using video streaming platforms.':'Overall Experiance',
                            '16. Would you like to give any suggestion for the improvement.':'Suggestion'},inplace=True
                )

# %%
data.columns
# Out:
# Index(['Timestamp', 'Video Streaming Platform(Y/N)', 'Frequency of VSPA',
#        'Currently Used VSPA', 'Types', 'Genres', 'Netflix Original Series',
#        'Prime Original Series', 'Hotstar Original Series',
#        'Hulu Original Series', 'Age', 'advertisement', 'Selection',
#        'Time Period', 'Features', 'Overall Experiance', 'Suggestion'],
#       dtype='object')

# %%
data
# Out:
#            Timestamp Video Streaming Platform(Y/N)        Frequency of VSPA  \
# 0     3/1/2021 16:41                           Yes  Once or twice in a week
# 1     3/1/2021 19:44                           Yes                  Monthly
# 2     3/1/2021 20:44                           Yes                    Daily
# 3     3/1/2021 20:45                           Yes                    Daily
# 4     3/2/2021 21:06                           Yes                    Daily
# ..               ...                           ...                      ...
# 237   4/12/2021 9:11                           Yes                    Daily
# 238   4/12/2021 9:12                           Yes  Once or twice in a week
# 239  4/12/2021 14:13                           Yes                    Daily
# 240  4/12/2021 23:13                           Yes                    Daily
# 241  4/12/2021 23:15                           Yes                    Daily
#
#                        Currently Used VSPA  \
# 0           Netflix, Amazon Prime, Hotstar
# 1                    Netflix, Amazon Prime
# 2     Netflix, Amazon Prime, Hotstar, Hulu
# 3                                     Hulu
# 4    Netflix, Amazon Prime, Hotstar, Zee 5
# ..                                     ...
# 237                Netflix, Prime, Hotstar
# 238                                Netflix
# 239                Netflix, Prime, Hotstar
# 240                                  Prime
# 241                         Netflix, Prime
#
#                                                  Types  \
# 0                          Original web series, Others
# 1                                               Movies
# 2    Original web series, Movies, Documentaries, Sp...
# 3                              Movies, Sports and News
# 4    Original web series, Movies, Documentaries, Sp...
# ..                                                 ...
# 237  Original web series, Movies, Documentaries, Sp...
# 238  Original web series, Movies, Documentaries, Sp...
# 239         Original web series, Movies, Documentaries
# 240                 Original web series, Documentaries
# 241         Original web series, Movies, Documentaries
#
#                                     Genres  \
# 0                           Comedy, Others
# 1                    Action, Drama, Comedy
# 2            Action, Drama, Comedy, Horror
# 3                                   Action
# 4                    Action, Drama, Comedy
# ..                                     ...
# 237          Action, Drama, Comedy, Horror
# 238                 Action, Comedy, Horror
# 239          Action, Drama, Comedy, Horror
# 240                          Drama, Comedy
# 241  Action, Drama, Comedy, Horror, others
#
#                                Netflix Original Series  \
# 0                          Money Heist, Standup Comedy
# 1                                          Money Heist
# 2    Sacred Games, 13 Reasons Why, The Witcher, Mon...
# 3                          13 Reasons Why, The Witcher
# 4    Sacred Games, 13 Reasons Why, The Witcher, Mon...
# ..                                                 ...
# 237  Sacred Games, 13 Reasons Why, The Witcher, Mon...
# 238  Sacred Games, 13 Reasons Why, The Witcher, Mon...
# 239                                     13 Reasons Why
# 240                                  None of the above
# 241           13 Reasons Why, The Witcher, Money Heist
#
#                                  Prime Original Series  \
# 0      Tandav, Standup Comedy , Family Man, Panchayat.
# 1              Standup Comedy , Family Man, Panchayat.
# 2    Mirjapur, Made in heaven, Tandav, Breath into ...
# 3    Made in heaven, Tandav, Breath into the shadow...
# 4    Mirjapur, Made in heaven, Tandav, Breath into ...
# ..                                                 ...
# 237                   Mirzapur, Made in heaven, Tandav
# 238                                           Mirzapur
# 239                                     Made in heaven
# 240                             Made in heaven, Tandav
# 241                                   Mirzapur, Tandav
#
#                                Hotstar Original Series  \
# 0                              None of the above, Scam
# 1                                    None of the above
# 2    Special OPS, Hostages, Criminal Justice, Arya,...
# 3                                       Hostages, Arya
# 4    Special OPS, Hostages, Criminal Justice, Arya,...
# ..                                                 ...
# 237            Special OPS, Hostages, Criminal Justice
# 238                                  None of the above
# 239            Special OPS, Hostages, Criminal Justice
# 240                                  None of the above
# 241                                  None of the above
#
#                                   Hulu Original Series    Age  \
# 0                                    None of the above  18-30
# 1                       The Ultimate Playlist of Noise  18-30
# 2    Helstorm, Monsterland, Woke, The Ultimate Play...  18-30
# 3                       Monsterland, None of the above  18-30
# 4                                    None of the above  18-30
# ..                                                 ...    ...
# 237                                  None of the above  18-30
# 238                                  None of the above  18-30
# 239                                               Woke  18-30
# 240                                  None of the above  31-50
# 241                                  None of the above  18-30
#
#                                          advertisement              Selection  \
# 0          Family/Friends Recommendation, Social Media            Cast, Story
# 1          Family/Friends Recommendation, Social Media        Story, Director
# 2    Family/Friends Recommendation, Television, Soc...                  Story
# 3                             Television, Social Media         Cast, Director
# 4    Family/Friends Recommendation, Television, Soc...            Cast, Story
# ..                                                 ...                    ...
# 237  Family/Friends Recommendation, Television, Soc...  Cast, Story, Director
# 238                      Family/Friends Recommendation                  Story
# 239  Family/Friends Recommendation, Television, Soc...  Cast, Story, Director
# 240                 Social Media, Ads on OTT platforms  Cast, Story, Director
# 241        Family/Friends Recommendation, Social Media            Cast, Story
#
#                Time Period                       Features Overall Experiance  \
# 0    Between 1 and 2 years    Recommendation, Ease of use               Good
# 1         Less than 1 year  Search option, Recommendation          Excellent
# 2    Between 1 and 2 years  Search option, Recommendation          Excellent
# 3        More than 2 years                    Ease of use          Excellent
# 4        More than 2 years    Recommendation, Ease of use          Excellent
# ..                     ...                            ...                ...
# 237  Between 1 and 2 years    Recommendation, Ease of use          Excellent
# 238      More than 2 years  Recommendation, Accessibility          Excellent
# 239  Between 1 and 2 years     Search option, Ease of use          Excellent
# 240  Between 1 and 2 years  Search option, Recommendation          Excellent
# 241  Between 1 and 2 years  Search option, Recommendation               Good
#
#                                      Suggestion
# 0                      Yes, faster next season.
# 1                                            No
# 2                                       Nothing
# 3                                       Nothing
# 4         Need more web series like Money Heist
# ..                                          ...
# 237                                 Remove adds
# 238                                 Remove adds
# 239                      Limit the add duration
# 240                                     No need
# 241  yes need to decrease the membership amount
#
# [242 rows x 17 columns]

# %%
data['Video Streaming Platform(Y/N)'].value_counts().plot(kind='pie',autopct='%1.2f%%',figsize=(10,8))
plt.title("Do you use Video Streaming Platform?")
plt.show()

# %%
data['Frequency of VSPA'].value_counts().plot(kind='bar',figsize=(15,8))
plt.title("How frequently you watch or stream online platforms ?")
plt.show()

# %%
data['Types'].value_counts().plot(kind='barh',figsize=(10,8))
plt.title("What do you watch the most on video streaming platform?")
plt.show()

# %%
data['Currently Used VSPA'].value_counts().plot(kind='barh',figsize=(20,10))
plt.title("Which of the following Video Streaming Platform do you currently use?")
plt.show()

# %%
data['Genres'].value_counts().plot(kind='bar',figsize=(20,10))
plt.title("Which type of web series or movies do you prefer most?")
plt.axhline(0, color="k");

# %%
data['Netflix Original Series'].value_counts().plot(kind='barh',figsize=(20,10))
plt.title(" Have you watch or familiar with these original web series of Netflix.")
plt.show()

# %%
data['Prime Original Series'].value_counts().plot(kind='barh',figsize=(20,10))
plt.title(" Have you watch or familiar with these original web series of Prime.")
plt.show()

# %%
data['Hotstar Original Series'].value_counts().plot(kind='bar',figsize=(20,10))
plt.title(" Have you watch or familiar with these original web series of Hotstar.")
plt.show()

# %%
data['Hulu Original Series'].value_counts().plot(kind='pie',figsize=(8,120))
plt.title(" Have you watch or familiar with these original web series of Hulu.")
plt.show()

# %%
data['advertisement'].value_counts().plot(kind='barh',figsize=(20,10))
plt.title(" From where did you get the idea of these web series.")
plt.show()

# %%
data['Time Period'].value_counts().plot(kind='barh',figsize=(20,10))
plt.title("How long you are using these video streaming platforms.")
plt.show()

# %%
data['Features'].value_counts().plot(kind='barh',figsize=(20,10))
plt.title("Choose the features which you think is essential on your streaming platforms.")
plt.show()

# %%
data['Overall Experiance'].value_counts().plot(kind='barh',figsize=(20,10))
plt.title(" How was your overall experience of using video streaming platforms.")
plt.show()

# %%
data['Selection'].value_counts().plot(kind='barh',figsize=(20,10))
plt.title("On what basis you choose your Web Series or Movies.")
plt.show()

# %%
data.columns
# Out:
# Index(['Timestamp', 'Video Streaming Platform(Y/N)', 'Frequency of VSPA',
#        'Currently Used VSPA', 'Types', 'Genres', 'Netflix Original Series',
#        'Prime Original Series', 'Hotstar Original Series',
#        'Hulu Original Series', 'Age', 'advertisement', 'Selection',
#        'Time Period', 'Features', 'Overall Experiance', 'Suggestion'],
#       dtype='object')

# %%
df = pd.DataFrame()

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["Netflix Original Series", "Prime Original Series", "Hotstar Original Series", "Hulu Original Series"])
df2.plot.bar(figsize=(10,10),stacked=True);

# %%
plt.figure();

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["Netflix Original Series", "Prime Original Series", "Hotstar Original Series", "Hulu Original Series"])
color = {
        "boxes": "DarkGreen",
        "whiskers": "DarkOrange",
        "medians": "DarkBlue",
        "caps": "Gray",
   }

df.plot.box(figsize=(10,10),color=color);

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Types', 'Genres'])

# %%
df.plot.area(figsize=(10,10));

# %%
 df = pd.DataFrame(np.random.randn(250, 2), columns=['Age', 'advertisement'])

# %%
df["advertisement"] = df["advertisement"] + np.arange(250)

# %%
df.plot.hexbin(x="Age", y="advertisement", gridsize=25,figsize=(10,10));
